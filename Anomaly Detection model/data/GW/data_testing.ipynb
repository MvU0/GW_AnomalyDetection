# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
test = pd.read_parquet('test_stand_CTWS.parquet')
val = pd.read_parquet('val_stand.parquet')
train = pd.read_parquet('train_stand.parquet')

# %%
print(test.shape)
print(val.shape)
print(train.shape)
# Out:
# (303104, 784)
# (149504, 783)
# (522240, 783)
